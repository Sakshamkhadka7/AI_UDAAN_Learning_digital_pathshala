# %%
import pandas as pd
result = pd.Series(["Nepal","France","Argentina"])
print(result)
# Out:
# 0        Nepal
# 1       France
# 2    Argentina
# dtype: str

# %%
number_series=pd.Series([10,20,30],index=[1,2,3])
print(number_series[3])
# Out:
# 30

# %%
student_data={
     "name":["Saksham","kuldeep","Milan"],
      "age":[19,20,21],
       "course":["ai_udaan","mern","javascript"]
}

student_frame=pd.DataFrame(student_data)
print(student_frame)
# Out:
#       name  age      course
# 0  Saksham   19    ai_udaan
# 1  kuldeep   20        mern
# 2    Milan   21  javascript

# %%
student_datas= pd.read_csv("datasets/studentdata.csv")
print(student_datas)
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0               7          56            8               7
# 1               4          69            5               3
# 2              11          60            7               6
# 3               8          99            9               8
# 4               5          52            8               6
# ...           ...         ...          ...             ...
# 9995            2          58            9               7
# 9996            7          98            6               9
# 9997           10          44            8               5
# 9998           10          75            7               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score placement_status
# 0                        10              62      100.00           Placed
# 1                         8              56      100.00           Placed
# ...

# %%
todos_datas= pd.read_json("datasets/todos.json")
print(todos_datas)
# Out:
#     userId  id                                              title  completed
# 0        1   1                                 delectus aut autem      False
# 1        1   2                 quis ut nam facilis et officia qui      False
# 2        1   3                                fugiat veniam minus      False
# 3        1   4                                   et porro tempora       True
# 4        1   5  laboriosam mollitia et enim quasi adipisci qui...      False
# 5        1   6  qui ullam ratione quibusdam voluptatem quia omnis      False
# 6        1   7                  illo expedita consequatur quia in      False
# 7        1   8                       quo adipisci enim quam ut ab       True
# 8        1   9                        molestiae perspiciatis ipsa      False
# 9        1  10       illo est ratione doloremque quia maiores aut       True
# 10       1  11                        vero rerum temporibus dolor       True
# ...

# %%
nd=pd.read_csv("datasets/netflix_dataset.csv")
# print(nd.head(2))
# print(nd.head())
# print(nd.tail())
# print(nd.tail(2))
# print(nd.sample(3))
# print(nd.shape)
# print(nd.columns)
# print(nd.dtypes)
# print(nd.info())
print(nd.describe())
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000
